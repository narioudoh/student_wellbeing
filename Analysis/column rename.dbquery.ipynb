-- %%
select * from `analysis`.`dev`.`student` limit 10;

ALTER TABLE analysis.dev.student RENAME COLUMN `Academic Pressure` TO Academic_Pressure;
ALTER TABLE student RENAME COLUMN `Work Pressure` TO Work_Pressure;
ALTER TABLE student RENAME COLUMN `Study Satisfaction` TO Study_Satisfaction;
ALTER TABLE student RENAME COLUMN `Job Satisfaction` TO Job_Satisfaction;
ALTER TABLE student RENAME COLUMN `Sleep Duration` TO Sleep_Duration;
ALTER TABLE student RENAME COLUMN `Dietary Habits` TO Dietary_Habits;
ALTER TABLE analysis.dev.student RENAME COLUMN `Have you ever had suicidal thoughts ?` TO suicidal_thoughts;
ALTER TABLE student RENAME COLUMN `Work/Study Hours` TO Work_Study_Hours;
ALTER TABLE student RENAME COLUMN `Financial Stress` TO Financial_Stress;
ALTER TABLE student RENAME COLUMN `Family History of Mental Illness` TO Family_History_of_Mental_Illness;
